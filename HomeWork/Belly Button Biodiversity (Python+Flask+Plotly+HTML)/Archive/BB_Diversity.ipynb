# %%
# Dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, desc
from flask import Flask, jsonify, render_template, request
import csv

# %%
engine = create_engine("sqlite:///DataSets/bellybutton_v2.sqlite")

# %%
base = automap_base()
base.prepare(engine, reflect=True)
# Save reference to the table
samples = base.classes.samples
samples_metadata = base.classes.sample_metadata
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
sample = '940'
sample_query = "samples." + sample
print(sample_query)
results = session.query(samples.otu_id, samples.otu_label).all()
#results = session.query(samples.otu_id, samples.otu_label, samples.940).all()
results
# Out:
# samples.940
# [(1,
#   'Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Halococcus'),
#  (2,
#   'Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Halococcus'),
#  (3,
#   'Archaea;Euryarchaeota;Halobacteria;Halobacteriales;Halobacteriaceae;Natronorubrum'),
#  (4,
#   'Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter'),
#  (5,
#   'Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter'),
#  (6,
#   'Archaea;Euryarchaeota;Methanobacteria;Methanobacteriales;Methanobacteriaceae;Methanobrevibacter'),
#  (7, 'Bacteria'),
#  (8, 'Bacteria'),
#  (9, 'Bacteria'),
#  (10, 'Bacteria'),
#  (11, 'Bacteria'),
#  (12, 'Bacteria'),
#  (13, 'Bacteria'),
#  (14, 'Bacteria'),
#  (15, 'Bacteria'),
#  (16, 'Bacteria'),
#  (17, 'Bacteria'),
#  (18, 'Bacteria'),
#  (19, 'Bacteria'),
#  (20, 'Bacteria'),
#  (21, 'Bacteria'),
#  (22, 'Bacteria'),
#  (23, 'Bacteria'),
# ...

# %%
# Query all samples
sample = 'BB_940'
sample_query = "samples." + sample
results = session.query(samples.otu_id, sample_query).all()
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# OperationalError: near ".940": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-103-7a47326ac752> in <module>()
#       2 sample = '940'
# ...

# %%
# Query all samples
results1 = session.query(samples_metadata.sample).all()
#results1

# %%
import sqlite3
connection = sqlite3.connect('bellybutton.sqlite')
cursor = connection.cursor()
cursor = connection.execute('select * from samples')
names = list(map(lambda x: x[0], cursor.description))
names
# Out:
# ['otu_id',
#  'otu_label',
#  '940',
#  '941',
#  '943',
#  '944',
#  '945',
#  '946',
#  '947',
#  '948',
#  '949',
#  '950',
#  '952',
#  '953',
#  '954',
#  '955',
#  '956',
#  '958',
#  '959',
#  '960',
#  '961',
#  '962',
#  '963',
#  '964',
#  '966',
#  '967',
#  '968',
#  '969',
#  '970',
#  '971',
#  '972',
#  '973',
#  '974',
#  '975',
#  '978',
#  '1233',
#  '1234',
#  '1235',
#  '1236',
#  '1237',
#  '1238',
#  '1242',
#  '1243',
#  '1246',
#  '1253',
#  '1254',
#  '1258',
#  '1259',
#  '1260',
#  '1264',
#  '1265',
#  '1273',
#  '1275',
#  '1276',
#  '1277',
#  '1278',
#  '1279',
#  '1280',
#  '1281',
#  '1282',
#  '1283',
#  '1284',
#  '1285',
#  '1286',
#  '1287',
#  '1288',
#  '1289',
#  '1290',
#  '1291',
#  '1292',
#  '1293',
#  '1294',
#  '1295',
#  '1296',
#  '1297',
#  '1298',
#  '1308',
#  '1309',
#  '1310',
#  '1374',
#  '1415',
#  '1439',
#  '1441',
#  '1443',
#  '1486',
#  '1487',
#  '1489',
#  '1490',
#  '1491',
#  '1494',
#  '1495',
#  '1497',
#  '1499',
# ...

# %%
#sample = '940'
#sample_query = "samples." + sample
#print(sample_query)
cursor.execute("SELECT samples.otu_id, samples.otu_label,samples.940 FROM samples")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-125-3375ccffbb7e> in <module>()
#       2 #sample_query = "samples." + sample
#       3 #print(sample_query)
# ----> 4 cursor.execute("SELECT samples.otu_id, samples.otu_label,samples.940 FROM samples")
#       5 rows = cursor.fetchall()
#       6 for row in rows:
#
# OperationalError: near ".940": syntax error
